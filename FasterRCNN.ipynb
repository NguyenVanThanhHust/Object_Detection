# %%
import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
from torchvision import transforms
import matplotlib.pyplot as plt
import numpy as np
import cv2
from PIL import Image

# %%
if torch.cuda.is_available():
    device = torch.device("cuda")
    print(torch.cuda.get_device_name(0))
else:
    print("There is no availble gpu")
# Out:
# Tesla V100-SXM2-32GB-LS

# %%
image = cv2.imread("291.jpg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
print(image.shape)
plt.imshow(image)
plt.show()
# Out:
# (384, 576, 3)

# %%
# Object information: a set of bounding boxes [ymin, xmin, ymax, xmax] and their labels 
bboxes = np.array([[160, 147, 260, 234], [139, 312, 200, 348]]) 
labels = np.array([1, 1]) # 0: background, 1: random label

# %%
# resize image to 800x800
img = cv2.resize(image, dsize=(800, 800), interpolation=cv2.INTER_CUBIC)
plt.imshow(img)
plt.show()

# %%
# List all the layers of VGG16
model = torchvision.models.vgg16(pretrained=False).to(device)
fe = list(model.features)
print(len(fe))
# Out:
# 31
